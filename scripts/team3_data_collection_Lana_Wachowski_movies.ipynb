# %%
import requests
import json
import pandas as pd
import numpy as np
import pymysql

# %%
Lana_Wachowski_url="https://api.themoviedb.org/3/discover/movie?api_key=36927ad1d2817ff0fa31947e47d186fd&with_crew=9340"
response = requests.get(Lana_Wachowski_url)
json_object = response.content
movie_data = json.loads(json_object)
movie_data
    #if idx == 100:
        #break
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/dB0CxRwLXJoOrRPUvsJjb2hnPtq.jpg',
#    'genre_ids': [28, 878],
#    'id': 624860,
#    'original_language': 'en',
#    'original_title': 'The Matrix Resurrections',
#    'overview': "Plagued by strange memories, Neo's life takes an unexpected turn when he finds himself back inside the Matrix.",
#    'popularity': 217.658,
#    'poster_path': '/xLNtaLaHudIzOqdEZ7R3lcDLrQQ.jpg',
#    'release_date': '2021-12-15',
#    'title': 'The Matrix Resurrections',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': '/xdIsccWAECo0YF9aTrPoMFUZiJo.jpg',
#    'genre_ids': [28],
#    'id': 22832,
#    'original_language': 'en',
#    'original_title': 'Ninja Assassin',
#    'overview': 'Ninja Assassin follows Raizo, one of the deadliest assassins in the world. Taken from the streets as a child, he was transformed into a trained killer by the Ozunu Clan, a secret society whose very existence is considered a myth. But haunted by the merciless execution of his friend by the Clan, Raizo breaks free from them and vanishes. Now he waits, preparing to exact his revenge.',
#    'popularity': 147.389,
#    'poster_path': '/eQdtVLcwloJ1oqVSdfxazZBYHtX.jpg',
#    'release_date': '2009-09-29',
#    'title': 'Ninja Assassin',
#    'video': False,
#    'vote_average': 6.5,
#    'vote_count': 1063},
#   {'adult': False,
#    'backdrop_path': '/waCRuAW5ocONRehP556vPexVXA9.jpg',
#    'genre_ids': [28, 878],
#    'id': 603,
#    'original_language': 'en',
#    'original_title': 'The Matrix',
#    'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#    'popularity': 154.038,
#    'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#    'release_date': '1999-03-30',
#    'title': 'The Matrix',
#    'video': False,
#    'vote_average': 8.2,
#    'vote_count': 20339},
#   {'adult': False,
#    'backdrop_path': '/tva2OlLELCagFynFibcefhn2D9i.jpg',
#    'genre_ids': [12, 28, 53, 878],
#    'id': 604,
#    'original_language': 'en',
#    'original_title': 'The Matrix Reloaded',
#    'overview': "Six months after the events depicted in The Matrix, Neo has proved to be a good omen for the free humans, as more and more humans are being freed from the matrix and brought to Zion, the one and only stronghold of the Resistance.  Neo himself has discovered his superpowers including super speed, ability to see the codes of the things inside the matrix and a certain degree of pre-cognition. But a nasty piece of news hits the human resistance: 250,000 machine sentinels are digging to Zion and would reach them in 72 hours. As Zion prepares for the ultimate war, Neo, Morpheus and Trinity are advised by the Oracle to find the Keymaker who would help them reach the Source.  Meanwhile Neo's recurrent dreams depicting Trinity's death have got him worried and as if it was not enough, Agent Smith has somehow escaped deletion, has become more powerful than before and has fixed Neo as his next target.",
#    'popularity': 89.124,
#    'poster_path': '/9TGHDvWrqKBzwDxDodHYXEmOE6J.jpg',
#    'release_date': '2003-05-15',
#    'title': 'The Matrix Reloaded',
#    'video': False,
#    'vote_average': 7,
#    'vote_count': 8355},
#   {'adult': False,
#    'backdrop_path': '/533xAMhhVyjTy8hwMUFEt5TuDfR.jpg',
#    'genre_ids': [12, 28, 53, 878],
#    'id': 605,
#    'original_language': 'en',
#    'original_title': 'The Matrix Revolutions',
#    'overview': 'The human city of Zion defends itself against the massive invasion of the machines as Neo fights to end the war at another front while also opposing the rogue Agent Smith.',
#    'popularity': 87.551,
#    'poster_path': '/fgm8OZ7o4G1G1I9EeGcb85Noe6L.jpg',
#    'release_date': '2003-11-05',
#    'title': 'The Matrix Revolutions',
#    'video': False,
#    'vote_average': 6.7,
#    'vote_count': 7477},
#   {'adult': False,
#    'backdrop_path': '/lGD5itDKjoOYXaVXVmGgubWMB7M.jpg',
#    'genre_ids': [878, 14, 28, 12],
#    'id': 76757,
#    'original_language': 'en',
#    'original_title': 'Jupiter Ascending',
#    'overview': 'In a universe where human genetic material is the most precious commodity, an impoverished young Earth woman becomes the key to strategic maneuvers and internal strife within a powerful dynasty…',
#    'popularity': 65.03,
#    'poster_path': '/2NCcAZ3M3F0FxENYmammBknwpVn.jpg',
#    'release_date': '2015-02-04',
#    'title': 'Jupiter Ascending',
#    'video': False,
#    'vote_average': 5.4,
#    'vote_count': 5701},
#   {'adult': False,
#    'backdrop_path': '/uF0yNBvxYeoNM85rfvLrPvIhGrp.jpg',
#    'genre_ids': [28, 53, 14],
#    'id': 752,
#    'original_language': 'en',
#    'original_title': 'V for Vendetta',
#    'overview': 'In a world in which Great Britain has become a fascist state, a masked vigilante known only as “V” conducts guerrilla warfare against the oppressive British government. When V rescues a young woman from the secret police, he finds in her an ally with whom he can continue his fight to free the people of Britain.',
#    'popularity': 23.84,
#    'poster_path': '/kxekpqZUpO5W65QT12goucFvyx9.jpg',
#    'release_date': '2006-02-23',
#    'title': 'V for Vendetta',
#    'video': False,
#    'vote_average': 7.9,
#    'vote_count': 11732},
#   {'adult': False,
#    'backdrop_path': '/6EnDIsjiel1qOfsIKQInwl80Zua.jpg',
#    'genre_ids': [16, 878],
#    'id': 55931,
#    'original_language': 'en',
#    'original_title': 'The Animatrix',
#    'overview': "Straight from the creators of the groundbreaking Matrix trilogy, this collection of short animated films from the world's leading anime directors fuses computer graphics and Japanese anime to provide the background of the Matrix universe and the conflict between man and machines. The shorts include Final Flight of the Osiris, The Second Renaissance, Kid's Story, Program, World Record, Beyond, A Detective Story and Matriculated.",
#    'popularity': 27.039,
#    'poster_path': '/g52SOsTvdjzY8oPIn5znLJMzLHG.jpg',
#    'release_date': '2003-05-09',
#    'title': 'The Animatrix',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 1143},
#   {'adult': False,
#    'backdrop_path': '/lBdXACywnLwKUZmZkZ87djDQBeV.jpg',
#    'genre_ids': [99],
#    'id': 14543,
#    'original_language': 'en',
#    'original_title': 'The Matrix Revisited',
#    'overview': 'The film goes behind the scenes of the 1999 sci-fi movie The Matrix.',
#    'popularity': 35.728,
#    'poster_path': '/fNG2JOskhQnttmAaj2knM5h59Io.jpg',
#    'release_date': '2001-11-19',
#    'title': 'The Matrix Revisited',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 150},
#   {'adult': False,
#    'backdrop_path': '/2lw4O1QOnJIVYaLrVuQyjtjwOuN.jpg',
#    'genre_ids': [18, 878],
#    'id': 83542,
#    'original_language': 'en',
#    'original_title': 'Cloud Atlas',
#    'overview': 'A set of six nested stories spanning time between the 19th century and a distant post-apocalyptic future. Cloud Atlas explores how the actions and consequences of individual lives impact one another throughout the past, the present and the future. Action, mystery and romance weave through the story as one soul is shaped from a killer into a hero and a single act of kindness ripples across centuries to inspire a revolution in the distant future.  Based on the award winning novel by David Mitchell. Directed by Tom Tykwer and the Wachowskis.',
#    'popularity': 26.735,
#    'poster_path': '/amNMifaMEd0FBOR289OcnRAJjTI.jpg',
#    'release_date': '2012-10-26',
#    'title': 'Cloud Atlas',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 5920},
#   {'adult': False,
#    'backdrop_path': '/kH14XvCHKfMRz1sNsAMY0KpAKb0.jpg',
#    'genre_ids': [10751, 28, 12, 35],
#    'id': 7459,
#    'original_language': 'en',
#    'original_title': 'Speed Racer',
#    'overview': 'Speed Racer is the tale of a young and brilliant racing driver. When corruption in the racing leagues costs his brother his life, he must team up with the police and the mysterious Racer X to bring an end to the corruption and criminal activities. Inspired by the cartoon series.',
#    'popularity': 20.503,
#    'poster_path': '/AdHSTkL9fe5J6Exc8RB9vX1YmmH.jpg',
#    'release_date': '2008-05-07',
#    'title': 'Speed Racer',
#    'video': False,
#    'vote_average': 6.2,
#    'vote_count': 1128},
#   {'adult': False,
#    'backdrop_path': '/ejaBMLY1IlNdmpgDD4Vy4xhdlkR.jpg',
#    'genre_ids': [28, 12, 80, 53],
#    'id': 9691,
#    'original_language': 'en',
#    'original_title': 'Assassins',
#    'overview': 'Assassin Robert Rath arrives at a funeral to kill a prominent mobster, only to witness a rival hired gun complete the job for him -- with grisly results. Horrified by the murder of innocent bystanders, Rath decides to take one last job and then return to civilian life. But finding his way out of the world of contract killing grows ever more dangerous as Rath falls for his female target and becomes a marked man himself.',
#    'popularity': 15.851,
#    'poster_path': '/wPmZYnaQpxwoHmwNwVhZ2IY0UbF.jpg',
#    'release_date': '1995-10-06',
#    'title': 'Assassins',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 1146},
#   {'adult': False,
#    'backdrop_path': '/mSIwogX33Hp09JEnahn5IbAODG.jpg',
#    'genre_ids': [18, 53],
#    'id': 9303,
#    'original_language': 'en',
#    'original_title': 'Bound',
#    'overview': 'Corky, a tough female ex-convict working on an apartment renovation in a Chicago building, meets a couple living next door, Caesar, a paranoid mobster, and Violet, his seductive girlfriend, who is immediately attracted to her.',
#    'popularity': 16.283,
#    'poster_path': '/9qAy6UWVw44dGrsyKrdEMt5qIUM.jpg',
#    'release_date': '1996-09-13',
#    'title': 'Bound',
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 601},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [878, 16],
#    'id': 24914,
#    'original_language': 'en',
#    'original_title': "Kid's Story",
#    'overview': 'A high school student is haunted by thoughts of "The Matrix" and a person named "Neo". Part of the Animatrix collection of animated shorts set in the Matrix universe.',
#    'popularity': 8.771,
#    'poster_path': '/x5U6hUgRzF3pdhL5daimvfr8QBW.jpg',
#    'release_date': '2003-06-03',
#    'title': "Kid's Story",
#    'video': False,
#    'vote_average': 7,
#    'vote_count': 101},
#   {'adult': False,
#    'backdrop_path': '/tT4BDO5fa2bL4ltzwjA326zffN0.jpg',
#    'genre_ids': [878, 28, 16],
#    'id': 24357,
#    'original_language': 'en',
#    'original_title': 'Final Flight of the Osiris',
#    'overview': 'Immediately before the events of The Matrix Reloaded, the crew of the hovercraft Osiris discovers a quarter of a million sentinels drilling through the surface of the earth towards the last human city of Zion. But can the Osiris survive long enough to warn Zion?',
#    'popularity': 8.943,
#    'poster_path': '/eg4AdBBOP2VCa9mZamYK45Wir1w.jpg',
#    'release_date': '2003-03-21',
#    'title': 'Final Flight of the Osiris',
#    'video': False,
#    'vote_average': 7,
#    'vote_count': 108},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [878, 16],
#    'id': 24362,
#    'original_language': 'en',
#    'original_title': 'The Second Renaissance Part II',
#    'overview': 'The battle for Earth turns against the humans, despite their infamous desperate act of blackening the skies.',
#    'popularity': 5.882,
#    'poster_path': '/gkKkVekgnVQommH5RNBqxqDeDUa.jpg',
#    'release_date': '2003-05-06',
#    'title': 'The Second Renaissance Part II',
#    'video': False,
#    'vote_average': 7.5,
#    'vote_count': 100},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [878, 16],
#    'id': 24358,
#    'original_language': 'en',
#    'original_title': 'The Second Renaissance Part I',
#    'overview': 'Tells the early history of how conflict began between the humans and machines. Part 1 of 2.',
#    'popularity': 5.319,
#    'poster_path': '/u5qtb9bUMoAP4Vc4wzIb9IC7I9d.jpg',
#    'release_date': '2003-02-04',
#    'title': 'The Second Renaissance Part I',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 107},
#   {'adult': False,
#    'backdrop_path': '/GTkHsE8acJby9JsWdP9fIY76qc.jpg',
#    'genre_ids': [99],
#    'id': 355131,
#    'original_language': 'en',
#    'original_title': 'Sense8: Creating the World',
#    'overview': 'Go behind the scenes and around the world with the "Sense8" cast and crew in this in-depth look at how the hit series is made.',
#    'popularity': 5.578,
#    'poster_path': '/nKZIcIqgu9wMiE7SpfwuFRJXKFs.jpg',
#    'release_date': '2015-08-01',
#    'title': 'Sense8: Creating the World',
#    'video': False,
#    'vote_average': 7.9,
#    'vote_count': 78}],
#  'total_pages': 1,
#  'total_results': 18}

# %%
# Lana_Wachowski가 대본을 쓴 영화

Lana_Wachowski_movies=pd.DataFrame(movie_data['results'])
Lana_Wachowski_movies.sort_values(by="vote_average", ascending=False)
# Out:
#     adult                     backdrop_path            genre_ids      id  \
# 2   False  /waCRuAW5ocONRehP556vPexVXA9.jpg            [28, 878]     603
# 17  False   /GTkHsE8acJby9JsWdP9fIY76qc.jpg                 [99]  355131
# 6   False  /uF0yNBvxYeoNM85rfvLrPvIhGrp.jpg         [28, 53, 14]     752
# 15  False                              None            [878, 16]   24362
# 16  False                              None            [878, 16]   24358
# 7   False  /6EnDIsjiel1qOfsIKQInwl80Zua.jpg            [16, 878]   55931
# 12  False   /mSIwogX33Hp09JEnahn5IbAODG.jpg             [18, 53]    9303
# 3   False  /tva2OlLELCagFynFibcefhn2D9i.jpg    [12, 28, 53, 878]     604
# 14  False  /tT4BDO5fa2bL4ltzwjA326zffN0.jpg        [878, 28, 16]   24357
# 13  False                              None            [878, 16]   24914
# 9   False  /2lw4O1QOnJIVYaLrVuQyjtjwOuN.jpg            [18, 878]   83542
# 8   False  /lBdXACywnLwKUZmZkZ87djDQBeV.jpg                 [99]   14543
# 4   False  /533xAMhhVyjTy8hwMUFEt5TuDfR.jpg    [12, 28, 53, 878]     605
# 1   False  /xdIsccWAECo0YF9aTrPoMFUZiJo.jpg                 [28]   22832
# 11  False  /ejaBMLY1IlNdmpgDD4Vy4xhdlkR.jpg     [28, 12, 80, 53]    9691
# 10  False  /kH14XvCHKfMRz1sNsAMY0KpAKb0.jpg  [10751, 28, 12, 35]    7459
# 5   False  /lGD5itDKjoOYXaVXVmGgubWMB7M.jpg    [878, 14, 28, 12]   76757
# 0   False  /dB0CxRwLXJoOrRPUvsJjb2hnPtq.jpg            [28, 878]  624860
#
#    original_language                  original_title  \
# 2                 en                      The Matrix
# 17                en      Sense8: Creating the World
# 6                 en                  V for Vendetta
# 15                en  The Second Renaissance Part II
# 16                en   The Second Renaissance Part I
# 7                 en                   The Animatrix
# 12                en                           Bound
# 3                 en             The Matrix Reloaded
# 14                en      Final Flight of the Osiris
# 13                en                     Kid's Story
# 9                 en                     Cloud Atlas
# 8                 en            The Matrix Revisited
# 4                 en          The Matrix Revolutions
# 1                 en                  Ninja Assassin
# 11                en                       Assassins
# 10                en                     Speed Racer
# 5                 en               Jupiter Ascending
# 0                 en        The Matrix Resurrections
#
#                                              overview  popularity  \
# 2   Set in the 22nd century, The Matrix tells the ...     154.038
# 17  Go behind the scenes and around the world with...       5.578
# 6   In a world in which Great Britain has become a...      23.840
# 15  The battle for Earth turns against the humans,...       5.882
# 16  Tells the early history of how conflict began ...       5.319
# 7   Straight from the creators of the groundbreaki...      27.039
# 12  Corky, a tough female ex-convict working on an...      16.283
# 3   Six months after the events depicted in The Ma...      89.124
# 14  Immediately before the events of The Matrix Re...       8.943
# 13  A high school student is haunted by thoughts o...       8.771
# 9   A set of six nested stories spanning time betw...      26.735
# 8   The film goes behind the scenes of the 1999 sc...      35.728
# 4   The human city of Zion defends itself against ...      87.551
# 1   Ninja Assassin follows Raizo, one of the deadl...     147.389
# 11  Assassin Robert Rath arrives at a funeral to k...      15.851
# 10  Speed Racer is the tale of a young and brillia...      20.503
# 5   In a universe where human genetic material is ...      65.030
# 0   Plagued by strange memories, Neo's life takes ...     217.658
#
#                          poster_path release_date  \
# 2   /f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg   1999-03-30
# 17  /nKZIcIqgu9wMiE7SpfwuFRJXKFs.jpg   2015-08-01
# 6   /kxekpqZUpO5W65QT12goucFvyx9.jpg   2006-02-23
# 15  /gkKkVekgnVQommH5RNBqxqDeDUa.jpg   2003-05-06
# 16  /u5qtb9bUMoAP4Vc4wzIb9IC7I9d.jpg   2003-02-04
# 7   /g52SOsTvdjzY8oPIn5znLJMzLHG.jpg   2003-05-09
# 12  /9qAy6UWVw44dGrsyKrdEMt5qIUM.jpg   1996-09-13
# 3   /9TGHDvWrqKBzwDxDodHYXEmOE6J.jpg   2003-05-15
# 14  /eg4AdBBOP2VCa9mZamYK45Wir1w.jpg   2003-03-21
# 13  /x5U6hUgRzF3pdhL5daimvfr8QBW.jpg   2003-06-03
# 9   /amNMifaMEd0FBOR289OcnRAJjTI.jpg   2012-10-26
# 8   /fNG2JOskhQnttmAaj2knM5h59Io.jpg   2001-11-19
# 4   /fgm8OZ7o4G1G1I9EeGcb85Noe6L.jpg   2003-11-05
# 1   /eQdtVLcwloJ1oqVSdfxazZBYHtX.jpg   2009-09-29
# 11  /wPmZYnaQpxwoHmwNwVhZ2IY0UbF.jpg   1995-10-06
# 10  /AdHSTkL9fe5J6Exc8RB9vX1YmmH.jpg   2008-05-07
# 5   /2NCcAZ3M3F0FxENYmammBknwpVn.jpg   2015-02-04
# 0   /xLNtaLaHudIzOqdEZ7R3lcDLrQQ.jpg   2021-12-15
#
#                              title  video  vote_average  vote_count
# 2                       The Matrix  False           8.2       20339
# 17      Sense8: Creating the World  False           7.9          78
# 6                   V for Vendetta  False           7.9       11732
# 15  The Second Renaissance Part II  False           7.5         100
# 16   The Second Renaissance Part I  False           7.4         107
# 7                    The Animatrix  False           7.2        1143
# 12                           Bound  False           7.1         601
# 3              The Matrix Reloaded  False           7.0        8355
# 14      Final Flight of the Osiris  False           7.0         108
# 13                     Kid's Story  False           7.0         101
# 9                      Cloud Atlas  False           6.9        5920
# 8             The Matrix Revisited  False           6.9         150
# 4           The Matrix Revolutions  False           6.7        7477
# 1                   Ninja Assassin  False           6.5        1063
# 11                       Assassins  False           6.4        1146
# 10                     Speed Racer  False           6.2        1128
# 5                Jupiter Ascending  False           5.4        5701
# 0         The Matrix Resurrections  False           0.0           0
