# %%
import requests
import json
import pandas as pd
import numpy as np
import pymysql
import pymysql
import os

# %%
Tom_Holland_url="https://api.themoviedb.org/3/discover/movie?api_key=36927ad1d2817ff0fa31947e47d186fd&with_cast=1136406"
response = requests.get(Tom_Holland_url)
json_object = response.content
movie_data = json.loads(json_object)
movie_data
    #if idx == 100:
        #break
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/lNyLSOKMMeUPr1RsL4KcRuIXwHt.jpg',
#    'genre_ids': [878, 28, 12],
#    'id': 580489,
#    'original_language': 'en',
#    'original_title': 'Venom: Let There Be Carnage',
#    'overview': 'After finding a host body in investigative reporter Eddie Brock, the alien symbiote must face a new enemy, Carnage, the alter ego of serial killer Cletus Kasady.',
#    'popularity': 8364.759,
#    'poster_path': '/rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg',
#    'release_date': '2021-09-30',
#    'title': 'Venom: Let There Be Carnage',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 4186},
#   {'adult': False,
#    'backdrop_path': '/vIPIyTJqcgOKgKcExCvTDpLpTYW.jpg',
#    'genre_ids': [28, 12, 878],
#    'id': 634649,
#    'original_language': 'en',
#    'original_title': 'Spider-Man: No Way Home',
#    'overview': 'Peter Parker is unmasked and no longer able to separate his normal life from the high-stakes of being a super-hero. When he asks for help from Doctor Strange the stakes become even more dangerous, forcing him to discover what it truly means to be Spider-Man.',
#    'popularity': 2098.473,
#    'poster_path': '/1g0dhYtq4irTY1GPXvft6k4YLjm.jpg',
#    'release_date': '2021-12-15',
#    'title': 'Spider-Man: No Way Home',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': '/ng6SSB3JhbcpKTwbPDsRwUYK8Cq.jpg',
#    'genre_ids': [28, 12, 878],
#    'id': 429617,
#    'original_language': 'en',
#    'original_title': 'Spider-Man: Far From Home',
#    'overview': 'Peter Parker and his friends go on a summer trip to Europe. However, they will hardly be able to rest - Peter will have to agree to help Nick Fury uncover the mystery of creatures that cause natural disasters and destruction throughout the continent.',
#    'popularity': 618.488,
#    'poster_path': '/4q2NNj4S5dG2RLF9CpXsej7yXl.jpg',
#    'release_date': '2019-06-28',
#    'title': 'Spider-Man: Far From Home',
#    'video': False,
#    'vote_average': 7.5,
#    'vote_count': 11144},
#   {'adult': False,
#    'backdrop_path': '/vc8bCGjdVp0UbMNLzHnHSLRbBWQ.jpg',
#    'genre_ids': [28, 12, 878, 18],
#    'id': 315635,
#    'original_language': 'en',
#    'original_title': 'Spider-Man: Homecoming',
#    'overview': 'Following the events of Captain America: Civil War, Peter Parker, with the help of his mentor Tony Stark, tries to balance his life as an ordinary high school student in Queens, New York City, with fighting crime as his superhero alter ego Spider-Man as a new threat, the Vulture, emerges.',
#    'popularity': 702.508,
#    'poster_path': '/c24sv2weTHPsmDa7jEMN0m2P3RT.jpg',
#    'release_date': '2017-07-05',
#    'title': 'Spider-Man: Homecoming',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 17284},
#   {'adult': False,
#    'backdrop_path': '/lmZFxXgJE3vgrciwuDib0N8CfQo.jpg',
#    'genre_ids': [12, 28, 878],
#    'id': 299536,
#    'original_language': 'en',
#    'original_title': 'Avengers: Infinity War',
#    'overview': 'As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth and existence itself has never been more uncertain.',
#    'popularity': 333.172,
#    'poster_path': '/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg',
#    'release_date': '2018-04-25',
#    'title': 'Avengers: Infinity War',
#    'video': False,
#    'vote_average': 8.3,
#    'vote_count': 23261},
#   {'adult': False,
#    'backdrop_path': '/7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg',
#    'genre_ids': [12, 878, 28],
#    'id': 299534,
#    'original_language': 'en',
#    'original_title': 'Avengers: Endgame',
#    'overview': "After the devastating events of Avengers: Infinity War, the universe is in ruins due to the efforts of the Mad Titan, Thanos. With the help of remaining allies, the Avengers must assemble once more in order to undo Thanos' actions and restore order to the universe once and for all, no matter what consequences may be in store.",
#    'popularity': 249.666,
#    'poster_path': '/or06FN3Dka5tukK1e9sl16pB3iy.jpg',
#    'release_date': '2019-04-24',
#    'title': 'Avengers: Endgame',
#    'video': False,
#    'vote_average': 8.3,
#    'vote_count': 19692},
#   {'adult': False,
#    'backdrop_path': '/7FWlcZq3r6525LWOcvO9kNWurN1.jpg',
#    'genre_ids': [12, 28, 878],
#    'id': 271110,
#    'original_language': 'en',
#    'original_title': 'Captain America: Civil War',
#    'overview': 'Following the events of Age of Ultron, the collective governments of the world pass an act designed to regulate all superhuman activity. This polarizes opinion amongst the Avengers, causing two factions to side with Iron Man or Captain America, which causes an epic battle between former allies.',
#    'popularity': 157.876,
#    'poster_path': '/rAGiXaUfPzY7CDEyNKUofk3Kw2e.jpg',
#    'release_date': '2016-04-27',
#    'title': 'Captain America: Civil War',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 18954},
#   {'adult': False,
#    'backdrop_path': '/ovggmAOu1IbPGTQE8lg4lBasNC7.jpg',
#    'genre_ids': [878],
#    'id': 412656,
#    'original_language': 'en',
#    'original_title': 'Chaos Walking',
#    'overview': 'Two unlikely companions embark on a perilous adventure through the badlands of an unexplored planet as they try to escape a dangerous and disorienting reality, where all inner thoughts are seen and heard by everyone.',
#    'popularity': 111.419,
#    'poster_path': '/9kg73Mg8WJKlB9Y2SAJzeDKAnuB.jpg',
#    'release_date': '2021-02-24',
#    'title': 'Chaos Walking',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 1410},
#   {'adult': False,
#    'backdrop_path': '/uQtqiAu2bBlokqjlURVLEha6zoi.jpg',
#    'genre_ids': [18, 80],
#    'id': 544401,
#    'original_language': 'en',
#    'original_title': 'Cherry',
#    'overview': 'Cherry drifts from college dropout to army medic in Iraq - anchored only by his true love, Emily. But after returning from the war with PTSD, his life spirals into drugs and crime as he struggles to find his place in the world.',
#    'popularity': 77.499,
#    'poster_path': '/pwDvkDyaHEU9V7cApQhbcSJMG1w.jpg',
#    'release_date': '2021-02-26',
#    'title': 'Cherry',
#    'video': False,
#    'vote_average': 7.5,
#    'vote_count': 811},
#   {'adult': False,
#    'backdrop_path': '/xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg',
#    'genre_ids': [10751, 16, 12, 35, 14],
#    'id': 508439,
#    'original_language': 'en',
#    'original_title': 'Onward',
#    'overview': 'In a suburban fantasy world, two teenage elf brothers embark on an extraordinary quest to discover if there is still a little magic left out there.',
#    'popularity': 51.458,
#    'poster_path': '/f4aul3FyD3jv3v4bul1IrkWZvzq.jpg',
#    'release_date': '2020-02-29',
#    'title': 'Onward',
#    'video': False,
#    'vote_average': 7.8,
#    'vote_count': 4687},
#   {'adult': False,
#    'backdrop_path': '/lwSOhnpwrzjtKi2RD3e5RAcGzvt.jpg',
#    'genre_ids': [16, 28, 12, 35, 10751],
#    'id': 431693,
#    'original_language': 'en',
#    'original_title': 'Spies in Disguise',
#    'overview': 'Super spy Lance Sterling and scientist Walter Beckett are almost exact opposites. Lance is smooth, suave and debonair. Walter is… not. But what Walter lacks in social skills he makes up for in smarts and invention, creating the awesome gadgets Lance uses on his epic missions. But when events take an unexpected turn, Walter and Lance suddenly have to rely on each other in a whole new way.',
#    'popularity': 31.467,
#    'poster_path': '/30YacPAcxpNemhhwX0PVUl9pVA3.jpg',
#    'release_date': '2019-12-04',
#    'title': 'Spies in Disguise',
#    'video': False,
#    'vote_average': 7.7,
#    'vote_count': 2110},
#   {'adult': False,
#    'backdrop_path': '/xcUf6yIheo78btFqihlRLftdR3M.jpg',
#    'genre_ids': [10751, 14, 12],
#    'id': 448119,
#    'original_language': 'en',
#    'original_title': 'Dolittle',
#    'overview': 'After losing his wife seven years earlier, the eccentric Dr. John Dolittle, famed doctor and veterinarian of Queen Victoria’s England, hermits himself away behind the high walls of Dolittle Manor with only his menagerie of exotic animals for company. But when the young queen falls gravely ill, a reluctant Dolittle is forced to set sail on an epic adventure to a mythical island in search of a cure, regaining his wit and courage as he crosses old adversaries and discovers wondrous creatures.',
#    'popularity': 34.039,
#    'poster_path': '/uoplwswBDy7gsOyrbGuKyPFoPCs.jpg',
#    'release_date': '2020-01-01',
#    'title': 'Dolittle',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 2756},
#   {'adult': False,
#    'backdrop_path': '/4U9F5zpsn2fEKTJCyX9u0DlyUAH.jpg',
#    'genre_ids': [99],
#    'id': 626329,
#    'original_language': 'en',
#    'original_title': "A Fan's Guide to Spider-Man: Homecoming",
#    'overview': 'Zendaya and Tom Holland give fans an exclusive behind-the-scenes look at Spider-Man Homecoming.',
#    'popularity': 21.515,
#    'poster_path': '/aXXkTxJbZJ8R9I3N47ekFiLkM1W.jpg',
#    'release_date': '2017-06-03',
#    'title': "A Fan's Guide to Spider-Man: Homecoming",
#    'video': False,
#    'vote_average': 8.3,
#    'vote_count': 7},
#   {'adult': False,
#    'backdrop_path': '/6xyZP1DgByVN2NbTgYwQFhQVFsv.jpg',
#    'genre_ids': [53, 18],
#    'id': 80278,
#    'original_language': 'en',
#    'original_title': 'The Impossible',
#    'overview': 'In December 2004, close-knit family Maria, Henry and their three sons begin their winter vacation in Thailand. But the day after Christmas, the idyllic holiday turns into an incomprehensible nightmare when a terrifying roar rises from the depths of the sea, followed by a wall of black water that devours everything in its path. Though Maria and her family face their darkest hour, unexpected displays of kindness and courage ameliorate their terror.',
#    'popularity': 23.656,
#    'poster_path': '/k0DLCiDbnYywOHiISALbl2EH2NE.jpg',
#    'release_date': '2012-09-09',
#    'title': 'The Impossible',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 5175},
#   {'adult': False,
#    'backdrop_path': '/fZCme3QpqXg1Y8T7xNl7kkatBNr.jpg',
#    'genre_ids': [53, 18, 12, 28, 36],
#    'id': 205775,
#    'original_language': 'en',
#    'original_title': 'In the Heart of the Sea',
#    'overview': 'In the winter of 1820, the New England whaling ship Essex is assaulted by something no one could believe—a whale of mammoth size and will, and an almost human sense of vengeance.',
#    'popularity': 21.367,
#    'poster_path': '/gLZEULfcS3uhfWDSEclOUgWiN41.jpg',
#    'release_date': '2015-11-20',
#    'title': 'In the Heart of the Sea',
#    'video': False,
#    'vote_average': 6.7,
#    'vote_count': 3239},
#   {'adult': False,
#    'backdrop_path': '/llJ9MACqlbqPieWCtPJnWIYrz6i.jpg',
#    'genre_ids': [28, 12, 18],
#    'id': 340442,
#    'original_language': 'en',
#    'original_title': 'Pilgrimage',
#    'overview': 'In 13th century Ireland a group of monks must escort a sacred relic across an Irish landscape fraught with peril.',
#    'popularity': 22.605,
#    'poster_path': '/lR5ilnIzIonItxL5mQPAPzXpwPJ.jpg',
#    'release_date': '2017-04-23',
#    'title': 'Pilgrimage',
#    'video': False,
#    'vote_average': 5.9,
#    'vote_count': 210},
#   {'adult': False,
#    'backdrop_path': '/rUeqBuNDR9zN6vZV9kpEFMtQm0E.jpg',
#    'genre_ids': [80, 18, 53],
#    'id': 499932,
#    'original_language': 'en',
#    'original_title': 'The Devil All the Time',
#    'overview': 'In Knockemstiff, Ohio and its neighboring backwoods, sinister characters converge around young Arvin Russell as he fights the evil forces that threaten him and his family.',
#    'popularity': 19.894,
#    'poster_path': '/bVL7LGq528h3KzeNI90HOVbV5uW.jpg',
#    'release_date': '2020-09-11',
#    'title': 'The Devil All the Time',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 2250},
#   {'adult': False,
#    'backdrop_path': '/qyAH7xkrgYCGPbaFV29C82Hngum.jpg',
#    'genre_ids': [12, 18, 36],
#    'id': 314095,
#    'original_language': 'en',
#    'original_title': 'The Lost City of Z',
#    'overview': 'A true-life drama in the 1920s, centering on British explorer Col. Percy Fawcett, who discovered evidence of a previously unknown, advanced civilization in the Amazon and disappeared whilst searching for it.',
#    'popularity': 25.8,
#    'poster_path': '/ik3ebv7J18fs6cHkmu91oxz7EGt.jpg',
#    'release_date': '2017-03-15',
#    'title': 'The Lost City of Z',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 2224},
#   {'adult': False,
#    'backdrop_path': '/cMC2akwLDkymydZU53ItCA7hOA5.jpg',
#    'genre_ids': [28, 12],
#    'id': 335787,
#    'original_language': 'en',
#    'original_title': 'Uncharted',
#    'overview': 'In an action-adventure epic that spans the globe, young street-smart Nathan Drake and his wisecracking partner Victor “Sully” Sullivan embark on a dangerous pursuit of “the greatest treasure never found” while also tracking clues that may lead to Nathan’s long-lost brother.',
#    'popularity': 20.769,
#    'poster_path': '/77dlklwA1VJOLCqIhhmkmS39BLH.jpg',
#    'release_date': '2022-02-10',
#    'title': 'Uncharted',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': '/nKEsNpMe8VFLsOWmB1KVX0TfyLM.jpg',
#    'genre_ids': [18, 53],
#    'id': 210479,
#    'original_language': 'en',
#    'original_title': 'Locke',
#    'overview': 'Ivan Locke has worked hard to craft a good life for himself. Tonight, that life will collapse around him. On the eve of the biggest challenge of his career, Ivan receives a phone call that sets in motion a series of events that will unravel his family, job, and soul.',
#    'popularity': 12.064,
#    'poster_path': '/fMotwVtyUr833goyv7EzgAp0bCR.jpg',
#    'release_date': '2014-04-10',
#    'title': 'Locke',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 2105}],
#  'total_pages': 2,
#  'total_results': 29}

# %%
# Tom Holland가 출연한 영화

Tom_Holland_movies=pd.DataFrame(movie_data['results'])
Tom_Holland_movies.sort_values(by="vote_average", ascending=False)
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 12  False  /4U9F5zpsn2fEKTJCyX9u0DlyUAH.jpg                     [99]  626329
# 4   False  /lmZFxXgJE3vgrciwuDib0N8CfQo.jpg            [12, 28, 878]  299536
# 5   False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg            [12, 878, 28]  299534
# 9   False  /xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg  [10751, 16, 12, 35, 14]  508439
# 10  False  /lwSOhnpwrzjtKi2RD3e5RAcGzvt.jpg  [16, 28, 12, 35, 10751]  431693
# 2   False  /ng6SSB3JhbcpKTwbPDsRwUYK8Cq.jpg            [28, 12, 878]  429617
# 8   False  /uQtqiAu2bBlokqjlURVLEha6zoi.jpg                 [18, 80]  544401
# 3   False  /vc8bCGjdVp0UbMNLzHnHSLRbBWQ.jpg        [28, 12, 878, 18]  315635
# 6   False  /7FWlcZq3r6525LWOcvO9kNWurN1.jpg            [12, 28, 878]  271110
# 16  False  /rUeqBuNDR9zN6vZV9kpEFMtQm0E.jpg             [80, 18, 53]  499932
# 13  False  /6xyZP1DgByVN2NbTgYwQFhQVFsv.jpg                 [53, 18]   80278
# 0   False  /lNyLSOKMMeUPr1RsL4KcRuIXwHt.jpg            [878, 28, 12]  580489
# 19  False  /nKEsNpMe8VFLsOWmB1KVX0TfyLM.jpg                 [18, 53]  210479
# 11  False  /xcUf6yIheo78btFqihlRLftdR3M.jpg          [10751, 14, 12]  448119
# 7   False  /ovggmAOu1IbPGTQE8lg4lBasNC7.jpg                    [878]  412656
# 14  False  /fZCme3QpqXg1Y8T7xNl7kkatBNr.jpg     [53, 18, 12, 28, 36]  205775
# 17  False  /qyAH7xkrgYCGPbaFV29C82Hngum.jpg             [12, 18, 36]  314095
# 15  False  /llJ9MACqlbqPieWCtPJnWIYrz6i.jpg             [28, 12, 18]  340442
# 1   False  /vIPIyTJqcgOKgKcExCvTDpLpTYW.jpg            [28, 12, 878]  634649
# 18  False  /cMC2akwLDkymydZU53ItCA7hOA5.jpg                 [28, 12]  335787
#
#    original_language                           original_title  \
# 12                en  A Fan's Guide to Spider-Man: Homecoming
# 4                 en                   Avengers: Infinity War
# 5                 en                        Avengers: Endgame
# 9                 en                                   Onward
# 10                en                        Spies in Disguise
# 2                 en                Spider-Man: Far From Home
# 8                 en                                   Cherry
# 3                 en                   Spider-Man: Homecoming
# 6                 en               Captain America: Civil War
# 16                en                   The Devil All the Time
# 13                en                           The Impossible
# 0                 en              Venom: Let There Be Carnage
# 19                en                                    Locke
# 11                en                                 Dolittle
# 7                 en                            Chaos Walking
# 14                en                  In the Heart of the Sea
# 17                en                       The Lost City of Z
# 15                en                               Pilgrimage
# 1                 en                  Spider-Man: No Way Home
# 18                en                                Uncharted
#
#                                              overview  popularity  \
# 12  Zendaya and Tom Holland give fans an exclusive...      21.515
# 4   As the Avengers and their allies have continue...     333.172
# 5   After the devastating events of Avengers: Infi...     249.666
# 9   In a suburban fantasy world, two teenage elf b...      51.458
# 10  Super spy Lance Sterling and scientist Walter ...      31.467
# 2   Peter Parker and his friends go on a summer tr...     618.488
# 8   Cherry drifts from college dropout to army med...      77.499
# 3   Following the events of Captain America: Civil...     702.508
# 6   Following the events of Age of Ultron, the col...     157.876
# 16  In Knockemstiff, Ohio and its neighboring back...      19.894
# 13  In December 2004, close-knit family Maria, Hen...      23.656
# 0   After finding a host body in investigative rep...    8364.759
# 19  Ivan Locke has worked hard to craft a good lif...      12.064
# 11  After losing his wife seven years earlier, the...      34.039
# 7   Two unlikely companions embark on a perilous a...     111.419
# 14  In the winter of 1820, the New England whaling...      21.367
# 17  A true-life drama in the 1920s, centering on B...      25.800
# 15  In 13th century Ireland a group of monks must ...      22.605
# 1   Peter Parker is unmasked and no longer able to...    2098.473
# 18  In an action-adventure epic that spans the glo...      20.769
#
#                          poster_path release_date  \
# 12  /aXXkTxJbZJ8R9I3N47ekFiLkM1W.jpg   2017-06-03
# 4   /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg   2018-04-25
# 5   /or06FN3Dka5tukK1e9sl16pB3iy.jpg   2019-04-24
# 9   /f4aul3FyD3jv3v4bul1IrkWZvzq.jpg   2020-02-29
# 10  /30YacPAcxpNemhhwX0PVUl9pVA3.jpg   2019-12-04
# 2    /4q2NNj4S5dG2RLF9CpXsej7yXl.jpg   2019-06-28
# 8   /pwDvkDyaHEU9V7cApQhbcSJMG1w.jpg   2021-02-26
# 3   /c24sv2weTHPsmDa7jEMN0m2P3RT.jpg   2017-07-05
# 6   /rAGiXaUfPzY7CDEyNKUofk3Kw2e.jpg   2016-04-27
# 16  /bVL7LGq528h3KzeNI90HOVbV5uW.jpg   2020-09-11
# 13  /k0DLCiDbnYywOHiISALbl2EH2NE.jpg   2012-09-09
# 0   /rjkmN1dniUHVYAtwuV3Tji7FsDO.jpg   2021-09-30
# 19  /fMotwVtyUr833goyv7EzgAp0bCR.jpg   2014-04-10
# 11  /uoplwswBDy7gsOyrbGuKyPFoPCs.jpg   2020-01-01
# 7   /9kg73Mg8WJKlB9Y2SAJzeDKAnuB.jpg   2021-02-24
# 14  /gLZEULfcS3uhfWDSEclOUgWiN41.jpg   2015-11-20
# 17  /ik3ebv7J18fs6cHkmu91oxz7EGt.jpg   2017-03-15
# 15  /lR5ilnIzIonItxL5mQPAPzXpwPJ.jpg   2017-04-23
# 1   /1g0dhYtq4irTY1GPXvft6k4YLjm.jpg   2021-12-15
# 18  /77dlklwA1VJOLCqIhhmkmS39BLH.jpg   2022-02-10
#
#                                       title  video  vote_average  vote_count
# 12  A Fan's Guide to Spider-Man: Homecoming  False           8.3           7
# 4                    Avengers: Infinity War  False           8.3       23261
# 5                         Avengers: Endgame  False           8.3       19692
# 9                                    Onward  False           7.8        4687
# 10                        Spies in Disguise  False           7.7        2110
# 2                 Spider-Man: Far From Home  False           7.5       11144
# 8                                    Cherry  False           7.5         811
# 3                    Spider-Man: Homecoming  False           7.4       17284
# 6                Captain America: Civil War  False           7.4       18954
# 16                   The Devil All the Time  False           7.3        2250
# 13                           The Impossible  False           7.3        5175
# 0               Venom: Let There Be Carnage  False           7.2        4186
# 19                                    Locke  False           6.9        2105
# 11                                 Dolittle  False           6.8        2756
# 7                             Chaos Walking  False           6.8        1410
# 14                  In the Heart of the Sea  False           6.7        3239
# 17                       The Lost City of Z  False           6.3        2224
# 15                               Pilgrimage  False           5.9         210
# 1                   Spider-Man: No Way Home  False           0.0           0
# 18                                Uncharted  False           0.0           0
