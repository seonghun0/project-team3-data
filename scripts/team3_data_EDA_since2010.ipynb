# %%
#!pip install seaborn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 2010.01.01~2021.11.26 영화리스트 csv파일 불러오기 
movies = pd.read_csv(r'C:\team3_data\project-team3-data\data-files\movies_2010_2021.csv',index_col=0)

# %%
# 원본 데이터프레임 보존
movies_backup=movies.copy()

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6727 entries, 0 to 6726
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          6727 non-null   object
#  1   movie_id           6727 non-null   int64
#  2   original_language  6727 non-null   object
#  3   subtitle           6727 non-null   object
#  4   overview           5334 non-null   object
#  5   popularity         6727 non-null   float64
#  6   posterpath         6726 non-null   object
#  7   release_date       6727 non-null   object
#  8   title              6727 non-null   object
#  9   vote_average       6727 non-null   float64
#  10  vote_count         6727 non-null   int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 630.7+ KB

# %%
movies.head()
movies.tail()
# Out:
#          genre_ids  movie_id original_language  \
# 6722   [18, 10752]    227306                en
# 6723   [10752, 28]    190859                en
# 6724  [53, 27, 18]    288158                en
# 6725  [80, 18, 53]    241239                en
# 6726          [35]    298614                fr
#
#                                   subtitle  \
# 6722                              Unbroken
# 6723                       American Sniper
# 6724  The Woman in Black 2: Angel of Death
# 6725                   A Most Violent Year
# 6726             Une heure de tranquillité
#
#                                                overview  popularity  \
# 6722  우유병에 술을 담아 마시고 몰래 담배를 피우며 꿈도, 미래에 대한 열정도 없던 반항...      28.042
# 6723  녹색 얼굴의 악마들, 전쟁의 종결자 네이비 실 사이에서도 전설이라 불렸던 남자 ‘크...     103.293
# 6724  한 명, 두 명 아이들이 사라지기 시작한다.  1941년 런던, 전쟁의 공습을 피해...      20.306
# 6725  "뛰어내리기가 무서울 때 바로 그때가 뛰어내릴 때죠" 원하는 것은 기필코 갖는 남자...      18.180
# 6726                                                NaN       8.730
#
# ...

# %%
movies.describe()
# Out:
#             movie_id    popularity  vote_average    vote_count
# count    6727.000000   6727.000000   6727.000000   6727.000000
# mean   324734.950795     34.289864      6.458094   1121.756355
# std    192409.746498    229.857375      0.857943   2355.974949
# min       189.000000      0.600000      2.100000     92.000000
# 25%    148274.500000      8.710000      5.900000    161.000000
# 50%    333385.000000     12.473000      6.500000    305.000000
# 75%    465122.500000     23.116000      7.100000    892.000000
# max    877183.000000  15909.335000      9.300000  30305.000000

# %%
movies.groupby(by="release_date")['popularity'].mean()
# Out:
# release_date
# 2010-01-01       9.9115
# 2010-01-05       6.4670
# 2010-01-07       6.6940
# 2010-01-08      39.4690
# 2010-01-11      28.0180
#                 ...
# 2021-11-04    3210.4065
# 2021-11-05      73.5900
# 2021-11-10    3129.2060
# 2021-11-11     333.6525
# 2021-11-12    1611.8755
# Name: popularity, Length: 2686, dtype: float64

# %%
movies.groupby(by="release_date")['popularity'].mean()
# Out:
# release_date
# 2010-01-01       9.9115
# 2010-01-05       6.4670
# 2010-01-07       6.6940
# 2010-01-08      39.4690
# 2010-01-11      28.0180
#                 ...
# 2021-11-04    3210.4065
# 2021-11-05      73.5900
# 2021-11-10    3129.2060
# 2021-11-11     333.6525
# 2021-11-12    1611.8755
# Name: popularity, Length: 2686, dtype: float64

# %%
movies.isnull().sum()
# Out:
# Unnamed: 0              0
# genre_ids               0
# movie_id                0
# original_language       0
# subtitle                0
# overview             1396
# popularity              0
# posterpath              1
# release_date            0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
# na 제거 (overview가 없는 1396개 행, posterpath가 없는 1행)
overview_na=~movies['overview'].isna()
overview_na_removed=movies[overview_na]
overview_na_removed.info()  # 5328 entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5328 entries, 0 to 6722
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5328 non-null   int64
#  1   genre_ids          5328 non-null   object
#  2   movie_id           5328 non-null   int64
#  3   original_language  5328 non-null   object
#  4   subtitle           5328 non-null   object
#  5   overview           5328 non-null   object
#  6   popularity         5328 non-null   float64
#  7   posterpath         5328 non-null   object
#  8   release_date       5328 non-null   object
#  9   title              5328 non-null   object
#  10  vote_average       5328 non-null   float64
#  11  vote_count         5328 non-null   int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 541.1+ KB

# %%
posterpath_na=~overview_na_removed['posterpath'].isna()
posterpath_na.sum()
# poster가 없는 영화 1개는 overview가 없는 영화에 포함되어 있음.
# Out:
# 5328

# %%
overview_na_removed.describe()
# Out:
#         Unnamed: 0       movie_id    popularity  vote_average    vote_count
# count  5328.000000    5328.000000   5328.000000   5328.000000   5328.000000
# mean   3303.888701  323045.404655     37.387529      6.487650   1354.914039
# std    1944.274946  192476.684120    206.946423      0.839461   2593.853528
# min       0.000000     189.000000      0.600000      2.700000    100.000000
# 25%    1634.750000  144936.250000      9.851250      5.900000    189.000000
# 50%    3275.500000  333159.000000     13.719000      6.500000    403.500000
# 75%    4980.250000  463338.250000     25.974500      7.100000   1177.250000
# max    6722.000000  876716.000000  11363.811000      9.300000  30291.000000

# %%
# release_date문자열을 datetime으로 변환 
overview_na_removed['release_date']=pd.to_datetime(overview_na_removed['release_date'],format='%Y-%m-%d')
# 월화수목금토일: 0~6
overview_na_removed.query('release_date.dt.dayofweek ==0')
# Out:
# C:\Users\bonomania\.conda\envs\ykseo\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Unnamed: 0               genre_ids  movie_id original_language  \
# 62            62           [16, 28, 878]    283566                ja
# 81            81                    [35]    595813                en
# 129          129                    [53]    666624                it
# 135          135            [28, 35, 53]    522931                en
# 139          139      [16, 9648, 28, 80]    736073                en
# ...          ...                     ...       ...               ...
# 6637        6637  [35, 18, 10402, 10749]    206296                en
# ...
