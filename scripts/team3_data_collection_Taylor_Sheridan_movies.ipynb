# %%
import requests
import json
import pandas as pd
import numpy as np
import pymysql

# %%
Taylor_Sheridan_url="https://api.themoviedb.org/3/discover/movie?api_key=36927ad1d2817ff0fa31947e47d186fd&with_crew=1215399"
response = requests.get(Taylor_Sheridan_url)
json_object = response.content
movie_data = json.loads(json_object)
movie_data
    #if idx == 100:
        #break
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/fPGeS6jgdLovQAKunNHX8l0avCy.jpg',
#    'genre_ids': [28, 53],
#    'id': 567189,
#    'original_language': 'en',
#    'original_title': "Tom Clancy's Without Remorse",
#    'overview': 'An elite Navy SEAL uncovers an international conspiracy while seeking justice for the murder of his pregnant wife.',
#    'popularity': 167.062,
#    'poster_path': '/6GCOpT8QcNzup09TAMmvvk22LTR.jpg',
#    'release_date': '2021-04-29',
#    'title': "Tom Clancy's Without Remorse",
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 1687},
#   {'adult': False,
#    'backdrop_path': '/ouOojiypBE6CD1aqcHPVq7cJf2R.jpg',
#    'genre_ids': [53],
#    'id': 578701,
#    'original_language': 'en',
#    'original_title': 'Those Who Wish Me Dead',
#    'overview': 'A young boy finds himself pursued by two assassins in the Montana wilderness, with a survival expert determined to protect him, and a forest fire threatening to consume them all.',
#    'popularity': 95.812,
#    'poster_path': '/xCEg6KowNISWvMh8GvPSxtdf9TO.jpg',
#    'release_date': '2021-05-05',
#    'title': 'Those Who Wish Me Dead',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 958},
#   {'adult': False,
#    'backdrop_path': '/4NdAMnBwSAaSsUjoXkcU5aW28RF.jpg',
#    'genre_ids': [28, 80, 53],
#    'id': 273481,
#    'original_language': 'en',
#    'original_title': 'Sicario',
#    'overview': 'An idealistic FBI agent is enlisted by a government task force to aid in the escalating war against drugs at the border area between the U.S. and Mexico.',
#    'popularity': 56.497,
#    'poster_path': '/tw0lXhbNkklvseuJ4aYldkVyXV7.jpg',
#    'release_date': '2015-09-17',
#    'title': 'Sicario',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 6557},
#   {'adult': False,
#    'backdrop_path': '/urMfgRUk0Kmf5p0KEJopAlqcyXm.jpg',
#    'genre_ids': [28, 80, 18, 53],
#    'id': 400535,
#    'original_language': 'en',
#    'original_title': 'Sicario: Day of the Soldado',
#    'overview': 'Agent Matt Graver teams up with operative Alejandro Gillick to prevent Mexican drug cartels from smuggling terrorists across the United States border.',
#    'popularity': 41.24,
#    'poster_path': '/msqWSQkU403cQKjQHnWLnugv7EY.jpg',
#    'release_date': '2018-06-27',
#    'title': 'Sicario: Day of the Soldado',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 2561},
#   {'adult': False,
#    'backdrop_path': '/kQGxGXzYiCumY8kmXXpgbZyZQK8.jpg',
#    'genre_ids': [80, 18, 9648, 53],
#    'id': 395834,
#    'original_language': 'en',
#    'original_title': 'Wind River',
#    'overview': "An FBI agent teams with the town's veteran game tracker to investigate a murder that occurred on a Native American reservation.",
#    'popularity': 27.925,
#    'poster_path': '/pySivdR845Hom4u4T2WNkJxe6Ad.jpg',
#    'release_date': '2017-08-03',
#    'title': 'Wind River',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 3835},
#   {'adult': False,
#    'backdrop_path': '/GZx3RAiTJAhXOdhLLyCAbqRl11.jpg',
#    'genre_ids': [37, 80],
#    'id': 338766,
#    'original_language': 'en',
#    'original_title': 'Hell or High Water',
#    'overview': "A divorced dad and his ex-con brother resort to a desperate scheme in order to save their family's farm in West Texas.",
#    'popularity': 18.407,
#    'poster_path': '/ljRRxqy2aXIkIBXLmOVifcOR021.jpg',
#    'release_date': '2016-08-12',
#    'title': 'Hell or High Water',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 3541},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [27, 53],
#    'id': 132064,
#    'original_language': 'en',
#    'original_title': 'Vile',
#    'overview': 'A group of people awaken to find themselves prisoners in a mysterious house with no means of escape. They are each outfitted with electronic devices attached to the base of their skulls. The chemicals that the brain produces when in pain are collected by the devices, and when it collects a predetermined amount, the doors will be opened. In order to escape, they must hurt themselves and each other.',
#    'popularity': 8.595,
#    'poster_path': '/wHxVSKv4plCpllQpBt4tOftKJ12.jpg',
#    'release_date': '2011-08-25',
#    'title': 'Vile',
#    'video': False,
#    'vote_average': 5,
#    'vote_count': 109},
#   {'adult': False,
#    'backdrop_path': '/j1bRxX8kQ30FNAUd1Q10hSaCHiI.jpg',
#    'genre_ids': [18, 53],
#    'id': 618009,
#    'original_language': 'en',
#    'original_title': 'Disorder',
#    'overview': 'A war veteran is hired to protect the family of a wealthy businessman.',
#    'popularity': 0.6,
#    'poster_path': '/6HdpM2P5Pzz8duG6CORA4NNpnVv.jpg',
#    'release_date': '',
#    'title': 'Disorder',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [53, 18],
#    'id': 556682,
#    'original_language': 'en',
#    'original_title': 'Fast',
#    'overview': 'A former special forces badass is recruited by the DEA to lead a covert black ops team to take down drug dealers that are protected by the CIA.',
#    'popularity': 0.6,
#    'poster_path': None,
#    'release_date': '',
#    'title': 'Fast',
#    'video': False,
#    'vote_average': 0,
#    'vote_count': 0}],
#  'total_pages': 1,
#  'total_results': 9}

# %%
# Taylor Sheridan이 감독한 영화

Taylor_Sheridan_movies=pd.DataFrame(movie_data['results'])
Taylor_Sheridan_movies.sort_values(by="vote_average", ascending=False)
# Out:
#    adult                     backdrop_path           genre_ids      id  \
# 2  False  /4NdAMnBwSAaSsUjoXkcU5aW28RF.jpg        [28, 80, 53]  273481
# 4  False  /kQGxGXzYiCumY8kmXXpgbZyZQK8.jpg  [80, 18, 9648, 53]  395834
# 5  False   /GZx3RAiTJAhXOdhLLyCAbqRl11.jpg            [37, 80]  338766
# 0  False  /fPGeS6jgdLovQAKunNHX8l0avCy.jpg            [28, 53]  567189
# 1  False  /ouOojiypBE6CD1aqcHPVq7cJf2R.jpg                [53]  578701
# 3  False  /urMfgRUk0Kmf5p0KEJopAlqcyXm.jpg    [28, 80, 18, 53]  400535
# 6  False                              None            [27, 53]  132064
# 7  False  /j1bRxX8kQ30FNAUd1Q10hSaCHiI.jpg            [18, 53]  618009
# 8  False                              None            [53, 18]  556682
#
#   original_language                original_title  \
# 2                en                       Sicario
# 4                en                    Wind River
# 5                en            Hell or High Water
# 0                en  Tom Clancy's Without Remorse
# 1                en        Those Who Wish Me Dead
# 3                en   Sicario: Day of the Soldado
# 6                en                          Vile
# 7                en                      Disorder
# 8                en                          Fast
#
#                                             overview  popularity  \
# 2  An idealistic FBI agent is enlisted by a gover...      56.497
# 4  An FBI agent teams with the town's veteran gam...      27.925
# 5  A divorced dad and his ex-con brother resort t...      18.407
# 0  An elite Navy SEAL uncovers an international c...     167.062
# 1  A young boy finds himself pursued by two assas...      95.812
# 3  Agent Matt Graver teams up with operative Alej...      41.240
# 6  A group of people awaken to find themselves pr...       8.595
# 7  A war veteran is hired to protect the family o...       0.600
# 8  A former special forces badass is recruited by...       0.600
#
#                         poster_path release_date  \
# 2  /tw0lXhbNkklvseuJ4aYldkVyXV7.jpg   2015-09-17
# 4  /pySivdR845Hom4u4T2WNkJxe6Ad.jpg   2017-08-03
# 5  /ljRRxqy2aXIkIBXLmOVifcOR021.jpg   2016-08-12
# 0  /6GCOpT8QcNzup09TAMmvvk22LTR.jpg   2021-04-29
# 1  /xCEg6KowNISWvMh8GvPSxtdf9TO.jpg   2021-05-05
# 3  /msqWSQkU403cQKjQHnWLnugv7EY.jpg   2018-06-27
# 6  /wHxVSKv4plCpllQpBt4tOftKJ12.jpg   2011-08-25
# 7  /6HdpM2P5Pzz8duG6CORA4NNpnVv.jpg
# 8                              None
#
#                           title  video  vote_average  vote_count
# 2                       Sicario  False           7.4        6557
# 4                    Wind River  False           7.4        3835
# 5            Hell or High Water  False           7.3        3541
# 0  Tom Clancy's Without Remorse  False           7.2        1687
# 1        Those Who Wish Me Dead  False           6.9         958
# 3   Sicario: Day of the Soldado  False           6.9        2561
# 6                          Vile  False           5.0         109
# 7                      Disorder  False           0.0           0
# 8                          Fast  False           0.0           0
